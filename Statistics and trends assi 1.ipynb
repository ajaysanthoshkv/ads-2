# %% [markdown]
# # Apple Quality Analysis

# %% [markdown]
# Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import skew
import seaborn as sns
from scipy.stats import kurtosis
df = pd.read_csv('apple_quality.csv')
print(df.head())
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0     0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1     1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2     2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3     3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#     Acidity Quality
# 0 -0.491590    good
# 1 -0.722809    good
# 2  2.621636     bad
# 3  0.790723    good
# 4  0.501984    good

# %%
apple_quality = pd.read_csv('apple_quality.csv',index_col='A_id')

# %%
apple_quality
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# A_id
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#        Acidity Quality
# A_id
# 0    -0.491590    good
# 1    -0.722809    good
# 2     2.621636     bad
# ...

# %%
apple_quality.describe()
# Out:
#               Size       Weight    Sweetness  Crunchiness    Juiciness  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean     -0.503015    -0.989547    -0.470479     0.985478     0.512118
# std       1.928059     1.602507     1.943441     1.402757     1.930286
# min      -7.151703    -7.149848    -6.894485    -6.055058    -5.961897
# 25%      -1.816765    -2.011770    -1.738425     0.062764    -0.801286
# 50%      -0.513703    -0.984736    -0.504758     0.998249     0.534219
# 75%       0.805526     0.030976     0.801922     1.894234     1.835976
# max       6.406367     5.790714     6.374916     7.619852     7.364403
#
#           Ripeness      Acidity
# count  4000.000000  4000.000000
# mean      0.498277     0.076877
# std       1.874427     2.110270
# min      -5.864599    -7.010538
# 25%      -0.771677    -1.377424
# 50%       0.503445     0.022609
# 75%       1.766212     1.510493
# max       7.237837     7.404736

# %%
apple_quality=apple_quality.select_dtypes(exclude=[object])

# %%
apple_quality.corr()
# Out:
#                  Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# Size         1.000000 -0.170702  -0.324680     0.169868  -0.018892 -0.134773
# Weight      -0.170702  1.000000  -0.154246    -0.095882  -0.092263 -0.243824
# Sweetness   -0.324680 -0.154246   1.000000    -0.037552   0.095882 -0.273800
# Crunchiness  0.169868 -0.095882  -0.037552     1.000000  -0.259607 -0.201982
# Juiciness   -0.018892 -0.092263   0.095882    -0.259607   1.000000 -0.097144
# Ripeness    -0.134773 -0.243824  -0.273800    -0.201982  -0.097144  1.000000
# Acidity      0.196218  0.016414   0.085999     0.069943   0.248714 -0.202669
#
#               Acidity
# Size         0.196218
# Weight       0.016414
# Sweetness    0.085999
# Crunchiness  0.069943
# Juiciness    0.248714
# Ripeness    -0.202669
# Acidity      1.000000

# %%
print(skew(apple_quality, axis=0, bias=True))
# Out:
# [-0.00243603  0.00310041  0.08381834  0.00023002 -0.1133783  -0.00876081
#   0.05576253]

# %%
print(kurtosis(apple_quality, axis=0, bias=True))
# Out:
# [-0.08473614  0.35710155  0.01295452  0.71961865  0.02719986 -0.07326005
#  -0.09483427]

# %%
# Create a histogram of a numerical variable
def histo_map():
    plt.hist(apple_quality['Acidity'], bins=20, color='skyblue', edgecolor='black')
    plt.title('Distribution of Data')
    plt.xlabel('Size')
    plt.ylabel('Weight')
    plt.show()
    plt.savefig('histogram.png')

# %%
histo_map()

# %%
# Create a line graph of trends over time
def scatter_map():
    plt.scatter(apple_quality['Juiciness'], apple_quality['Ripeness'], color='green')
    plt.title('Juiciness Over Ripeness')
    plt.xlabel('Juiciness')
    plt.ylabel('Ripeness')
    plt.yscale('log')
    plt.show()
    plt.savefig('scatter.png')

# %%
scatter_map()

# %%
non_numeric_cols = df.select_dtypes(exclude=['number']).columns
print("Non-numeric columns:", non_numeric_cols)

# Handle non-numeric values
# For example, you can encode categorical variables or handle missing values
# For simplicity, we'll just drop non-numeric columns in this example
df_numeric = df.select_dtypes(include=['number'])

# Calculate correlation matrix
correlation_matrix = df_numeric.corr()

# Display correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Non-numeric columns: Index(['Quality'], dtype='object')
# Correlation Matrix:
#                  A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  \
# A_id         1.000000 -0.028911 -0.005730  -0.002378    -0.013111   0.006179
# Size        -0.028911  1.000000 -0.170702  -0.324680     0.169868  -0.018892
# Weight      -0.005730 -0.170702  1.000000  -0.154246    -0.095882  -0.092263
# Sweetness   -0.002378 -0.324680 -0.154246   1.000000    -0.037552   0.095882
# Crunchiness -0.013111  0.169868 -0.095882  -0.037552     1.000000  -0.259607
# Juiciness    0.006179 -0.018892 -0.092263   0.095882    -0.259607   1.000000
# Ripeness     0.000742 -0.134773 -0.243824  -0.273800    -0.201982  -0.097144
# Acidity     -0.022237  0.196218  0.016414   0.085999     0.069943   0.248714
#
#              Ripeness   Acidity
# A_id         0.000742 -0.022237
# Size        -0.134773  0.196218
# Weight      -0.243824  0.016414
# Sweetness   -0.273800  0.085999
# Crunchiness -0.201982  0.069943
# ...

# %%
# Create a correlation heatmap
def corr_map():
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
    plt.title('Correlation Matrix')
    plt.show()
    plt.savefig('Heatmap.png')

# %%
corr_map()
